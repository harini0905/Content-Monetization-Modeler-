# %% [markdown]
# # 📺 Content Monetization Modeler

# %% [markdown]
# # import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # Load the dataset

# %%
url = "C:\Content Monetization Modeler Project\youtube_ad_revenue_dataset.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    video_id                        date  views   likes  comments  \
# 0  vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1  vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2  vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3  vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4  vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
#
#    watch_time_minutes  video_length_minutes  subscribers       category  \
# 0        26497.214184              2.862137       228086  Entertainment
# 1        15209.747445             23.738069       736015         Gaming
# 2        57332.658498             26.200634       240534      Education
# 3        31334.517771             11.770340       434482  Entertainment
# 4        15665.666434              6.635854        42030      Education
#
#    device country  ad_revenue_usd
# 0      TV      IN      203.178237
# 1  Tablet      CA      140.880508
# 2      TV      CA      360.134008
# ...

# %%
df.tail()
# Out:
#         video_id                        date  views   likes  comments  \
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers   category  \
# 122395        42075.704885             25.490195       210818  Education
# 122396        57563.703040             16.229133       878860      Music
# 122397        27549.714659             23.822365       576756       Tech
# 122398        56967.384382              7.753099       585138      Music
# 122399        38466.837135             27.305703       517587       Tech
#
#          device country  ad_revenue_usd
# 122395   Tablet      US      280.986396
# ...

# %% [markdown]
# # Check shape of data

# %%
df.shape
# Out:
# (122400, 12)

# %% [markdown]
# # Check sum of null values present in each column

# %%
df.isnull().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6117
# comments                6112
# watch_time_minutes      6105
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %% [markdown]
# # Check Percentage of null values present in each column

# %%
100*df.isnull().sum()/df.shape[0]
# Out:
# video_id                0.000000
# date                    0.000000
# views                   0.000000
# likes                   4.997549
# comments                4.993464
# watch_time_minutes      4.987745
# video_length_minutes    0.000000
# subscribers             0.000000
# category                0.000000
# device                  0.000000
# country                 0.000000
# ad_revenue_usd          0.000000
# dtype: float64

# %% [markdown]
# # Check datatype of column

# %%
df.dtypes
# Out:
# video_id                 object
# date                     object
# views                     int64
# likes                   float64
# comments                float64
# watch_time_minutes      float64
# video_length_minutes    float64
# subscribers               int64
# category                 object
# device                   object
# country                  object
# ad_revenue_usd          float64
# dtype: object

# %% [markdown]
# # Prints all columns

# %%
print(df.columns)
# Out:
# Index(['video_id', 'date', 'views', 'likes', 'comments', 'watch_time_minutes',
#        'video_length_minutes', 'subscribers', 'category', 'device', 'country',
#        'ad_revenue_usd'],
#       dtype='object')

# %%
df['likes']
# Out:
# 0         1221.0
# 1          642.0
# 2         1979.0
# 3         1191.0
# 4         1858.0
#            ...
# 122395    1673.0
# 122396    1709.0
# 122397     700.0
# 122398    1616.0
# 122399     770.0
# Name: likes, Length: 122400, dtype: float64

# %%
df['likes'] = df['likes'].astype('Int64')

# %%
print(df['likes'].dtype)
# Out:
# Int64

# %%
df['likes']
# Out:
# 0         1221
# 1          642
# 2         1979
# 3         1191
# 4         1858
#           ...
# 122395    1673
# 122396    1709
# 122397     700
# 122398    1616
# 122399     770
# Name: likes, Length: 122400, dtype: Int64

# %% [markdown]
# # Check duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(2400)

# %% [markdown]
# # Drop duplicate values

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### "The dataset contained 2,400 duplicate records (approximately 2% of the data). These duplicates were identified using df.duplicated().sum() and removed using drop_duplicates() to improve data quality and prevent biased analysis."

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape[0]
# Out:
# 120000

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['time'] = df['date'].dt.time

# %%
df.head()
# Out:
#    video_id                       date  views  likes  comments  \
# 0  vid_3092 2024-09-24 10:50:40.993199   9936   1221     320.0
# 1  vid_3459 2024-09-22 10:50:40.993199  10017    642     346.0
# 2  vid_4784 2024-11-21 10:50:40.993199  10097   1979     187.0
# 3  vid_4078 2025-01-28 10:50:40.993199  10034   1191     242.0
# 4  vid_3522 2025-04-28 10:50:40.993199   9889   1858     477.0
#
#    watch_time_minutes  video_length_minutes  subscribers       category  \
# 0        26497.214184              2.862137       228086  Entertainment
# 1        15209.747445             23.738069       736015         Gaming
# 2        57332.658498             26.200634       240534      Education
# 3        31334.517771             11.770340       434482  Entertainment
# 4        15665.666434              6.635854        42030      Education
#
#    device country  ad_revenue_usd  year      month  day             time
# 0      TV      IN      203.178237  2024  September   24  10:50:40.993199
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Handling Missing Values in likes column

# %%
df = df.copy()

df['likes'] = df['likes'].fillna(df['likes'].median())

# %%
df['likes'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Missing Values in comments and watch_time_minutes

# %%
df = df.copy()

df['comments'] = df['comments'].fillna(df['comments'].median())
df['watch_time_minutes'] = df['watch_time_minutes'].fillna(df['watch_time_minutes'].median())

# %% [markdown]
# # Statistics check

# %%
df.describe()
# Out:
#                                 date          views        likes  \
# count                         120000  120000.000000     120000.0
# mean   2024-12-08 03:24:11.233198848    9999.832333  1099.705792
# min       2024-06-09 10:50:40.993199    9521.000000        195.0
# 25%    2024-09-07 10:50:40.993199104    9933.000000        673.0
# 50%    2024-12-08 10:50:40.993199104   10000.000000       1102.0
# 75%    2025-03-09 10:50:40.993199104   10067.000000       1524.0
# max       2025-06-08 10:50:40.993199   10468.000000       2061.0
# std                              NaN      99.918405   506.372185
#
#             comments  watch_time_minutes  video_length_minutes    subscribers  \
# count  120000.000000       120000.000000         120000.000000  120000.000000
# mean      274.332350        37539.823485             16.017910  502291.970050
# min        48.000000        14659.105562              2.000142    1005.000000
# ...

# %% [markdown]
# 1. Identify Trends 📈

# %% [markdown]
# A. Views by Category

# %%
df.groupby('category')['views'].mean().sort_values(ascending=False)
# Out:
# category
# Music            10000.379915
# Entertainment    10000.106367
# Education         9999.914078
# Lifestyle         9999.808137
# Gaming            9999.773706
# Tech              9999.009986
# Name: views, dtype: float64

# %% [markdown]
# B. Revenue by Country

# %%
df.groupby('country')['ad_revenue_usd'].sum().sort_values(ascending=False)
# Out:
# country
# CA    5.106761e+06
# DE    5.095423e+06
# IN    5.089260e+06
# AU    5.026759e+06
# UK    5.024095e+06
# US    4.983066e+06
# Name: ad_revenue_usd, dtype: float64

# %% [markdown]
# C. Device-wise Performance

# %%
df.groupby('device')['watch_time_minutes'].mean().sort_values(ascending=False)
# Out:
# device
# Mobile     37653.092814
# Tablet     37586.814831
# TV         37471.525936
# Desktop    37448.141198
# Name: watch_time_minutes, dtype: float64

# %% [markdown]
# D. Monthly Trend

# %%
df.groupby('month')['views'].sum()
# Out:
# month
# April         97992621
# August       103172683
# December     100958875
# February      91518116
# January      102757642
# July         101058787
# June          98404195
# March        103030493
# May          101662878
# November      98426549
# October      103069722
# September     97927319
# Name: views, dtype: int64

# %% [markdown]
# 2. Identify Correlations

# %%
num_cols = [
    'views',
    'likes',
    'comments',
    'watch_time_minutes',
    'subscribers',
    'ad_revenue_usd'
]

# %%
df[num_cols].corr()
# Out:
#                        views     likes  comments  watch_time_minutes  \
# views               1.000000  0.015200  0.018141            0.026065
# likes               0.015200  1.000000 -0.002032            0.002722
# comments            0.018141 -0.002032  1.000000           -0.000713
# watch_time_minutes  0.026065  0.002722 -0.000713            1.000000
# subscribers         0.000750  0.003524 -0.001525            0.004617
# ad_revenue_usd      0.037942  0.142571  0.033630            0.964052
#
#                     subscribers  ad_revenue_usd
# views                  0.000750        0.037942
# likes                  0.003524        0.142571
# comments              -0.001525        0.033630
# watch_time_minutes     0.004617        0.964052
# subscribers            1.000000        0.005065
# ad_revenue_usd         0.005065        1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True)
plt.show()

# %% [markdown]
# 3. Identify Outliers 🚨

# %% [markdown]
# Boxplot for Views

# %%
import seaborn as sns

sns.boxplot(x=df['views'])
# Out:
# <Axes: xlabel='views'>

# %% [markdown]
# Boxplot for revenue

# %%
sns.boxplot(x=df['ad_revenue_usd'])
# Out:
# <Axes: xlabel='ad_revenue_usd'>

# %% [markdown]
# Using IQR Method

# %%
Q1 = df['views'].quantile(0.25)
Q3 = df['views'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['views'] < lower) | (df['views'] > upper)]

print("Outliers:", len(outliers))
# Out:
# Outliers: 865

# %%
Q1 = df['ad_revenue_usd'].quantile(0.25)
Q3 = df['ad_revenue_usd'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['ad_revenue_usd'] < lower) | (df['ad_revenue_usd'] > upper)]

print("Outliers:", len(outliers))
# Out:
# Outliers: 0

# %%
outliers = df[(df['views'] < lower) | (df['views'] > upper)]

outliers.head(10)
# Out:
#    video_id                       date  views  likes  comments  \
# 0  vid_3092 2024-09-24 10:50:40.993199   9936   1221     320.0
# 1  vid_3459 2024-09-22 10:50:40.993199  10017    642     346.0
# 2  vid_4784 2024-11-21 10:50:40.993199  10097   1979     187.0
# 3  vid_4078 2025-01-28 10:50:40.993199  10034   1191     242.0
# 4  vid_3522 2025-04-28 10:50:40.993199   9889   1858     477.0
# 5  vid_5000 2025-03-31 10:50:40.993199  10002    843     159.0
# 6  vid_2041 2024-12-10 10:50:40.993199   9989   1944     160.0
# 7  vid_3623 2025-04-05 10:50:40.993199  10051    784     458.0
# 8   vid_750 2025-02-17 10:50:40.993199   9934    292      88.0
# 9  vid_4434 2025-04-16 10:50:40.993199  10051   1102      61.0
#
#    watch_time_minutes  video_length_minutes  subscribers       category  \
# 0        26497.214184              2.862137       228086  Entertainment
# 1        15209.747445             23.738069       736015         Gaming
# ...

# %% [markdown]
# A boxplot was used to analyze the distribution of ad_revenue_usd. The visualization showed no significant outliers, indicating that ad revenue values are distributed within a reasonable range. The median revenue was approximately 255 USD, with most observations falling between 200 USD and 310 USD.

# %% [markdown]
# # One hot encoding

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['video_id', 'category', 'device', 'country', 'month', 'time'], dtype='object')

# %%
df_encoded = pd.get_dummies(
    df,
    columns=['category', 'device', 'country'],
    drop_first=True
)

# %%
print(df_encoded.columns)
# Out:
# Index(['video_id', 'date', 'views', 'likes', 'comments', 'watch_time_minutes',
#        'video_length_minutes', 'subscribers', 'ad_revenue_usd', 'year',
#        'month', 'day', 'time', 'category_Entertainment', 'category_Gaming',
#        'category_Lifestyle', 'category_Music', 'category_Tech',
#        'device_Mobile', 'device_TV', 'device_Tablet', 'country_CA',
#        'country_DE', 'country_IN', 'country_UK', 'country_US'],
#       dtype='object')

# %%
df_encoded.head()
# Out:
#    video_id                       date  views  likes  comments  \
# 0  vid_3092 2024-09-24 10:50:40.993199   9936   1221     320.0
# 1  vid_3459 2024-09-22 10:50:40.993199  10017    642     346.0
# 2  vid_4784 2024-11-21 10:50:40.993199  10097   1979     187.0
# 3  vid_4078 2025-01-28 10:50:40.993199  10034   1191     242.0
# 4  vid_3522 2025-04-28 10:50:40.993199   9889   1858     477.0
#
#    watch_time_minutes  video_length_minutes  subscribers  ad_revenue_usd  \
# 0        26497.214184              2.862137       228086      203.178237
# 1        15209.747445             23.738069       736015      140.880508
# 2        57332.658498             26.200634       240534      360.134008
# 3        31334.517771             11.770340       434482      224.638261
# 4        15665.666434              6.635854        42030      165.514388
#
#    year  ... category_Music  category_Tech device_Mobile  device_TV  \
# 0  2024  ...          False          False         False       True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120000 entries, 0 to 122399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              120000 non-null  object
#  1   date                  120000 non-null  datetime64[ns]
#  2   views                 120000 non-null  int64
#  3   likes                 120000 non-null  Int64
#  4   comments              120000 non-null  float64
#  5   watch_time_minutes    120000 non-null  float64
#  6   video_length_minutes  120000 non-null  float64
#  7   subscribers           120000 non-null  int64
#  8   category              120000 non-null  object
#  9   device                120000 non-null  object
#  10  country               120000 non-null  object
#  11  ad_revenue_usd        120000 non-null  float64
#  12  year                  120000 non-null  int32
#  13  month                 120000 non-null  object
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_encoded.head()
# Out:
#    video_id                       date  views  likes  comments  \
# 0  vid_3092 2024-09-24 10:50:40.993199   9936   1221     320.0
# 1  vid_3459 2024-09-22 10:50:40.993199  10017    642     346.0
# 2  vid_4784 2024-11-21 10:50:40.993199  10097   1979     187.0
# 3  vid_4078 2025-01-28 10:50:40.993199  10034   1191     242.0
# 4  vid_3522 2025-04-28 10:50:40.993199   9889   1858     477.0
#
#    watch_time_minutes  video_length_minutes  subscribers  ad_revenue_usd  \
# 0        26497.214184              2.862137       228086      203.178237
# 1        15209.747445             23.738069       736015      140.880508
# 2        57332.658498             26.200634       240534      360.134008
# 3        31334.517771             11.770340       434482      224.638261
# 4        15665.666434              6.635854        42030      165.514388
#
#    year      month  day             time  category_Entertainment  \
# 0  2024  September   24  10:50:40.993199                    True
# ...

# %%
pd.DataFrame(df_encoded.dtypes, columns=['Data Type'])
# Out:
#                              Data Type
# video_id                        object
# date                    datetime64[ns]
# views                            int64
# likes                            Int64
# comments                       float64
# watch_time_minutes             float64
# video_length_minutes           float64
# subscribers                      int64
# ad_revenue_usd                 float64
# year                             int32
# month                           object
# day                              int32
# time                            object
# category_Entertainment            bool
# category_Gaming                   bool
# category_Lifestyle                bool
# category_Music                    bool
# category_Tech                     bool
# device_Mobile                     bool
# device_TV                         bool
# device_Tablet                     bool
# country_CA                        bool
# country_DE                        bool
# ...

# %%
#independent variables
x = df.drop(['ad_revenue_usd'],axis = 1)

#dependent variable
y = df['ad_revenue_usd']

# %%
# Drop unnecessary columns
x = x.drop(['video_id', 'date'], axis=1)

# %%
x = pd.get_dummies(
    x,
    columns=['category', 'device', 'country', 'month', 'time'],
    drop_first=True
)

# %%
print(x.shape)
print(x.dtypes)
# Out:
# (120000, 32)
# views                       int64
# likes                       Int64
# comments                  float64
# watch_time_minutes        float64
# video_length_minutes      float64
# subscribers                 int64
# year                        int32
# day                         int32
# category_Entertainment       bool
# category_Gaming              bool
# category_Lifestyle           bool
# category_Music               bool
# category_Tech                bool
# device_Mobile                bool
# device_TV                    bool
# device_Tablet                bool
# country_CA                   bool
# country_DE                   bool
# country_IN                   bool
# country_UK                   bool
# country_US                   bool
# month_August                 bool
# month_December               bool
# month_February               bool
# month_January                bool
# month_July                   bool
# month_June                   bool
# ...

# %%
#splitting the data into test and train set
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
print(x.shape)
print(x.isnull().sum().sum())
# Out:
# (120000, 32)
# 0

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

lr = LinearRegression()
lr.fit(x_train_scaled, y_train)

y_pred_lr = lr.predict(x_test_scaled)

print("Linear Regression")
print("R2 Score:", r2_score(y_test, y_pred_lr))
print("MAE:", mean_absolute_error(y_test, y_pred_lr))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_lr)))
# Out:
# Linear Regression
# R2 Score: 0.9519344563980037
# MAE: 3.167897126701706
# RMSE: 13.601936645730984

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=42)
dt.fit(x_train, y_train)

y_pred_dt = dt.predict(x_test)

print("Decision Tree")
print("R2 Score:", r2_score(y_test, y_pred_dt))
print("MAE:", mean_absolute_error(y_test, y_pred_dt))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_dt)))
# Out:
# Decision Tree
# R2 Score: 0.8921199415216927
# MAE: 5.790608490132033
# RMSE: 20.377664378183766

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=20,
    max_depth=10,
    random_state=42,
    n_jobs=-1
)

rf.fit(x_train, y_train)

y_pred_rf = rf.predict(x_test)

print("Random Forest")
print("R2 Score:", r2_score(y_test, y_pred_rf))
print("MAE:", mean_absolute_error(y_test, y_pred_rf))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_rf)))
# Out:
# Random Forest
# R2 Score: 0.9509825421301402
# MAE: 3.98779897765177
# RMSE: 13.735966109178722

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(random_state=42)

gb.fit(x_train, y_train)

y_pred_gb = gb.predict(x_test)

print("Gradient Boosting")
print("R2 Score:", r2_score(y_test, y_pred_gb))
print("MAE:", mean_absolute_error(y_test, y_pred_gb))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_gb)))
# Out:
# Gradient Boosting
# R2 Score: 0.9516878433859662
# MAE: 3.6910411646470216
# RMSE: 13.636786172431064

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(
    n_neighbors=5
)

knn.fit(x_train_scaled, y_train)

y_pred_knn = knn.predict(x_test_scaled)

print("KNN Regressor")
print("R2 Score:", r2_score(y_test, y_pred_knn))
print("MAE:", mean_absolute_error(y_test, y_pred_knn))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_knn)))
# Out:
# KNN Regressor
# R2 Score: 0.6622272427005652
# MAE: 29.05579360821204
# RMSE: 36.05754282939379

# %%
results = pd.DataFrame({
    'Model': [
        'Linear Regression',
        'Decision Tree',
        'Random Forest',
        'Gradient Boosting',
        'KNN Regressor'
    ],
    'R2 Score': [
        r2_score(y_test, y_pred_lr),
        r2_score(y_test, y_pred_dt),
        r2_score(y_test, y_pred_rf),
        r2_score(y_test, y_pred_gb),
        r2_score(y_test, y_pred_knn)
    ],
    'MAE': [
        mean_absolute_error(y_test, y_pred_lr),
        mean_absolute_error(y_test, y_pred_dt),
        mean_absolute_error(y_test, y_pred_rf),
        mean_absolute_error(y_test, y_pred_gb),
        mean_absolute_error(y_test, y_pred_knn)
    ],
    'RMSE': [
        np.sqrt(mean_squared_error(y_test, y_pred_lr)),
        np.sqrt(mean_squared_error(y_test, y_pred_dt)),
        np.sqrt(mean_squared_error(y_test, y_pred_rf)),
        np.sqrt(mean_squared_error(y_test, y_pred_gb)),
        np.sqrt(mean_squared_error(y_test, y_pred_knn))
    ]
})

results = results.sort_values(by='R2 Score', ascending=False)

print(results)
# Out:
#                Model  R2 Score        MAE       RMSE
# 0  Linear Regression  0.951934   3.167897  13.601937
# 3  Gradient Boosting  0.951688   3.691041  13.636786
# 2      Random Forest  0.950983   3.987799  13.735966
# 1      Decision Tree  0.892120   5.790608  20.377664
# 4      KNN Regressor  0.662227  29.055794  36.057543

# %% [markdown]
# ### Model Evaluation and Results
#
# Five regression algorithms were evaluated for predicting YouTube ad revenue: Linear Regression, Decision Tree Regressor, Random Forest Regressor, Gradient Boosting Regressor, and K-Nearest Neighbors (KNN) Regressor.
#
# Model performance was assessed using R² Score, Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE).
#
# Among all models, Linear Regression achieved the best overall performance with an R² Score of 0.9519, MAE of 3.17, and RMSE of 13.60. This indicates that the model explains approximately 95% of the variability in ad revenue and provides highly accurate predictions.
#
# Gradient Boosting and Random Forest also performed exceptionally well, achieving similar results. However, Linear Regression slightly outperformed them across all evaluation metrics and was selected as the final model for deployment.
#
# The KNN Regressor showed the weakest performance, suggesting that neighborhood-based predictions were less effective for this dataset.

# %%
import pickle

with open('youtube_ad_revenue_model.pkl', 'wb') as file:
    pickle.dump(lr, file)

with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
feature_importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Coefficient': lr.coef_
})

feature_importance['Abs_Coefficient'] = abs(feature_importance['Coefficient'])

feature_importance = feature_importance.sort_values(
    by='Abs_Coefficient',
    ascending=False
)

print(feature_importance.head(10))
# Out:
#                Feature  Coefficient  Abs_Coefficient
# 3   watch_time_minutes    59.629768        59.629768
# 1                likes     8.646330         8.646330
# 2             comments     2.110869         2.110869
# 0                views     0.644627         0.644627
# 6                 year     0.212059         0.212059
# 31     month_September     0.183270         0.183270
# 29      month_November     0.157100         0.157100
# 22      month_December     0.132819         0.132819
# 25          month_July     0.125666         0.125666
# 21        month_August     0.111638         0.111638

# %%
print(feature_importance.head(10))
# Out:
#                Feature  Coefficient  Abs_Coefficient
# 3   watch_time_minutes    59.629768        59.629768
# 1                likes     8.646330         8.646330
# 2             comments     2.110869         2.110869
# 0                views     0.644627         0.644627
# 6                 year     0.212059         0.212059
# 31     month_September     0.183270         0.183270
# 29      month_November     0.157100         0.157100
# 22      month_December     0.132819         0.132819
# 25          month_July     0.125666         0.125666
# 21        month_August     0.111638         0.111638

# %% [markdown]
# ### Key Insights
#
# Feature importance analysis revealed that watch time is the most significant factor influencing YouTube ad revenue. Videos with longer average watch durations generate substantially higher revenue compared to videos with lower viewer retention.
#
# Engagement metrics such as likes and comments also contribute significantly to revenue generation, highlighting the importance of audience interaction and content quality.
#
# Although view count remains an important metric, the analysis suggests that viewer engagement and watch time have a stronger impact on ad revenue than views alone.
#
# Seasonal trends were also observed, with certain months such as September, November, and December showing slightly higher revenue contributions, likely due to increased advertiser spending during these periods.

# %%
print(x_train.columns.tolist())
# Out:
# ['views', 'likes', 'comments', 'watch_time_minutes', 'video_length_minutes', 'subscribers', 'year', 'day', 'category_Entertainment', 'category_Gaming', 'category_Lifestyle', 'category_Music', 'category_Tech', 'device_Mobile', 'device_TV', 'device_Tablet', 'country_CA', 'country_DE', 'country_IN', 'country_UK', 'country_US', 'month_August', 'month_December', 'month_February', 'month_January', 'month_July', 'month_June', 'month_March', 'month_May', 'month_November', 'month_October', 'month_September']
